# %%
import yaml
import csv
import pandas as pd

# %%
with open ('hgcroc_0_settings_20250818_210728.yaml','r') as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)

# %%
data.keys()
# Out:
# dict_keys(['CALIB_0', 'CALIB_1', 'CH_0', 'CH_1', 'CH_10', 'CH_11', 'CH_12', 'CH_13', 'CH_14', 'CH_15', 'CH_16', 'CH_17', 'CH_18', 'CH_19', 'CH_2', 'CH_20', 'CH_21', 'CH_22', 'CH_23', 'CH_24', 'CH_25', 'CH_26', 'CH_27', 'CH_28', 'CH_29', 'CH_3', 'CH_30', 'CH_31', 'CH_32', 'CH_33', 'CH_34', 'CH_35', 'CH_36', 'CH_37', 'CH_38', 'CH_39', 'CH_4', 'CH_40', 'CH_41', 'CH_42', 'CH_43', 'CH_44', 'CH_45', 'CH_46', 'CH_47', 'CH_48', 'CH_49', 'CH_5', 'CH_50', 'CH_51', 'CH_52', 'CH_53', 'CH_54', 'CH_55', 'CH_56', 'CH_57', 'CH_58', 'CH_59', 'CH_6', 'CH_60', 'CH_61', 'CH_62', 'CH_63', 'CH_64', 'CH_65', 'CH_66', 'CH_67', 'CH_68', 'CH_69', 'CH_7', 'CH_70', 'CH_71', 'CH_8', 'CH_9', 'CM_0', 'CM_1', 'CM_2', 'CM_3', 'DIGITALHALF_0', 'DIGITALHALF_1', 'GLOBALANALOG_0', 'GLOBALANALOG_1', 'HALFWISE_0', 'HALFWISE_1', 'MASTERTDC_0', 'MASTERTDC_1', 'REFERENCEVOLTAGE_0', 'REFERENCEVOLTAGE_1', 'TOP'])

# %%
data['CH_31']
# Out:
# {'ADC_PEDESTAL': 0,
#  'CHANNEL_OFF': 0,
#  'DACB': 0,
#  'DAC_CAL_CTDC_TOA': 0,
#  'DAC_CAL_CTDC_TOT': 0,
#  'DAC_CAL_FTDC_TOA': 0,
#  'DAC_CAL_FTDC_TOT': 0,
#  'DIS_TDC': 0,
#  'EXTDATA': 0,
#  'GAIN_CONV': 0,
#  'HIGHRANGE': 0,
#  'HZ_INV': 0,
#  'HZ_NOINV': 0,
#  'INPUTDAC': 0,
#  'IN_FTDC_ENCODER_TOA': 0,
#  'IN_FTDC_ENCODER_TOT': 0,
#  'LOWRANGE': 0,
#  'MASK_ADC': 0,
#  'MASK_ALIGNBUFFER': 0,
#  'MASK_TOA': 0,
#  'MASK_TOT': 0,
#  'PROBE_INV': 0,
#  'PROBE_NOINV': 0,
#  'PROBE_PA': 0,
#  'PROBE_TOA': 0,
#  'PROBE_TOT': 0,
#  'SEL_TRIG_TOA': 0,
#  'SEL_TRIG_TOT': 0,
#  'SIGN_DAC': 0,
#  'TRIM_INV': 7,
#  'TRIM_TOA': 0,
#  'TRIM_TOT': 0}

# %%
data['REFERENCEVOLTAGE_1']
# Out:
# {'CALIB': 0,
#  'CALIB_2V5': 0,
#  'CHOICE_CINJ': 0,
#  'CMD_120P': 0,
#  'DAC_ALDO': 0,
#  'EXTCTEST': 0,
#  'EXTCTEST_2V5': 0,
#  'INTCTEST': 0,
#  'INV_VREF': 416,
#  'NOINV_VREF': 832,
#  'ON_DAC': 1,
#  'PROBE_DC': 0,
#  'PROBE_DC1': 0,
#  'PROBE_DC2': 0,
#  'PROBE_VIN': 0,
#  'REFI': 3,
#  'TOA_VREF': 112,
#  'TOT_VREF': 432,
#  'VBG_1V': 5}

# %%
print ("Link 0 INV_VREF = " + str(data['REFERENCEVOLTAGE_0']['INV_VREF']) +" Link 0 NOINV_VREF = " + str(data['REFERENCEVOLTAGE_0']['NOINV_VREF']))
# Out:
# Link 0 INV_VREF = 416 Link 0 NOINV_VREF = 832

# %%
print ("Link 1 INV_VREF = " + str(data['REFERENCEVOLTAGE_1']['INV_VREF']) +" Link 1 NOINV_VREF = " + str(data['REFERENCEVOLTAGE_1']['NOINV_VREF']))
# Out:
# Link 1 INV_VREF = 416 Link 1 NOINV_VREF = 832

# %%
data['HALFWISE_0']
# Out:
# {'ADC_PEDESTAL': 0,
#  'CHANNEL_OFF': 0,
#  'DACB': 0,
#  'DAC_CAL_CTDC_TOA': 0,
#  'DAC_CAL_CTDC_TOT': 0,
#  'DAC_CAL_FTDC_TOA': 0,
#  'DAC_CAL_FTDC_TOT': 0,
#  'DIS_TDC': 0,
#  'EXTDATA': 0,
#  'GAIN_CONV': 0,
#  'HIGHRANGE': 0,
#  'HZ_INV': 0,
#  'HZ_NOINV': 0,
#  'INPUTDAC': 0,
#  'IN_FTDC_ENCODER_TOA': 0,
#  'IN_FTDC_ENCODER_TOT': 0,
#  'LOWRANGE': 0,
#  'MASK_ADC': 0,
#  'MASK_ALIGNBUFFER': 0,
#  'MASK_TOA': 0,
#  'MASK_TOT': 0,
#  'PROBE_INV': 0,
#  'PROBE_NOINV': 0,
#  'PROBE_PA': 0,
#  'PROBE_TOA': 0,
#  'PROBE_TOT': 0,
#  'SEL_TRIG_TOA': 0,
#  'SEL_TRIG_TOT': 0,
#  'SIGN_DAC': 0,
#  'TRIM_INV': 0,
#  'TRIM_TOA': 0,
#  'TRIM_TOT': 0}

# %%
data["DIGITALHALF_0"]
# Out:
# {'ADC_TH': 0,
#  'BX_OFFSET': 1,
#  'BX_TRIGGER': 15,
#  'CALIBRATIONSC': 0,
#  'CLRADCTOT_TRIG': 0,
#  'IDLEFRAME': 214748364,
#  'L1OFFSET': 16,
#  'MULTFACTOR': 25,
#  'OFF_LDO_RAM2': 0,
#  'SC_TESTRAM': -858993460,
#  'SELTC4': 1,
#  'TOT_P0': 0,
#  'TOT_P1': 0,
#  'TOT_P2': 0,
#  'TOT_P3': 0,
#  'TOT_P_ADD': 0,
#  'TOT_TH0': 0,
#  'TOT_TH1': 0,
#  'TOT_TH2': 0,
#  'TOT_TH3': 0}

# %%
with open ('test_ped_twice_leveled.yaml','r') as f:
    test_settings = yaml.load(f, Loader=yaml.SafeLoader)

# %%
test_settings.keys()
# Out:
# dict_keys(['CALIB_0', 'CALIB_1', 'CH_0', 'CH_1', 'CH_10', 'CH_11', 'CH_12', 'CH_13', 'CH_14', 'CH_15', 'CH_16', 'CH_17', 'CH_18', 'CH_19', 'CH_2', 'CH_20', 'CH_21', 'CH_22', 'CH_23', 'CH_24', 'CH_25', 'CH_26', 'CH_27', 'CH_28', 'CH_29', 'CH_3', 'CH_30', 'CH_31', 'CH_32', 'CH_33', 'CH_34', 'CH_35', 'CH_36', 'CH_37', 'CH_38', 'CH_39', 'CH_4', 'CH_40', 'CH_41', 'CH_42', 'CH_43', 'CH_44', 'CH_45', 'CH_46', 'CH_47', 'CH_48', 'CH_49', 'CH_5', 'CH_50', 'CH_51', 'CH_52', 'CH_53', 'CH_54', 'CH_55', 'CH_56', 'CH_57', 'CH_58', 'CH_59', 'CH_6', 'CH_60', 'CH_61', 'CH_62', 'CH_63', 'CH_64', 'CH_65', 'CH_66', 'CH_67', 'CH_68', 'CH_69', 'CH_7', 'CH_70', 'CH_71', 'CH_8', 'CH_9', 'CM_0', 'CM_1', 'CM_2', 'CM_3', 'DIGITALHALF_0', 'DIGITALHALF_1', 'GLOBALANALOG_0', 'GLOBALANALOG_1', 'HALFWISE_0', 'HALFWISE_1', 'MASTERTDC_0', 'MASTERTDC_1', 'REFERENCEVOLTAGE_0', 'REFERENCEVOLTAGE_1', 'TOP'])

# %%
test_settings['REFERENCEVOLTAGE_0']
# Out:
# {'CALIB': 0,
#  'CALIB_2V5': 0,
#  'CHOICE_CINJ': 0,
#  'CMD_120P': 0,
#  'DAC_ALDO': 0,
#  'EXTCTEST': 0,
#  'EXTCTEST_2V5': 0,
#  'INTCTEST': 0,
#  'INV_VREF': 527,
#  'NOINV_VREF': 832,
#  'ON_DAC': 1,
#  'PROBE_DC': 0,
#  'PROBE_DC1': 0,
#  'PROBE_DC2': 0,
#  'PROBE_VIN': 0,
#  'REFI': 3,
#  'TOA_VREF': 112,
#  'TOT_VREF': 432,
#  'VBG_1V': 5}

# %%
print ("Link 0 INV_VREF = " + str(test_settings['REFERENCEVOLTAGE_0']['INV_VREF']) +" Link 0 NOINV_VREF = " + str(test_settings['REFERENCEVOLTAGE_0']['NOINV_VREF']))
print ("Link 1 INV_VREF = " + str(test_settings['REFERENCEVOLTAGE_1']['INV_VREF']) +" Link 1 NOINV_VREF = " + str(test_settings['REFERENCEVOLTAGE_1']['NOINV_VREF']))
# Out:
# Link 0 INV_VREF = 527 Link 0 NOINV_VREF = 832
# Link 1 INV_VREF = 524 Link 1 NOINV_VREF = 832

# %%
test_settings["CH_1"]
# Out:
# {'ADC_PEDESTAL': 0,
#  'CHANNEL_OFF': 0,
#  'DACB': 0,
#  'DAC_CAL_CTDC_TOA': 0,
#  'DAC_CAL_CTDC_TOT': 0,
#  'DAC_CAL_FTDC_TOA': 0,
#  'DAC_CAL_FTDC_TOT': 0,
#  'DIS_TDC': 0,
#  'EXTDATA': 0,
#  'GAIN_CONV': 0,
#  'HIGHRANGE': 0,
#  'HZ_INV': 0,
#  'HZ_NOINV': 0,
#  'INPUTDAC': 0,
#  'IN_FTDC_ENCODER_TOA': 0,
#  'IN_FTDC_ENCODER_TOT': 0,
#  'LOWRANGE': 0,
#  'MASK_ADC': 0,
#  'MASK_ALIGNBUFFER': 0,
#  'MASK_TOA': 0,
#  'MASK_TOT': 0,
#  'PROBE_INV': 0,
#  'PROBE_NOINV': 0,
#  'PROBE_PA': 0,
#  'PROBE_TOA': 0,
#  'PROBE_TOT': 0,
#  'SEL_TRIG_TOA': 0,
#  'SEL_TRIG_TOT': 0,
#  'SIGN_DAC': 0,
#  'TRIM_INV': 63,
#  'TRIM_TOA': 0,
#  'TRIM_TOT': 0}

# %%
del test_settings["DIGITALHALF_1"]["SC_TESTRAM"]

# %%
dacb_values = []
trim_inv_values = []
inv_vref_values = []

# %%
for i in range (400,600):
    inv_vref_values.append(i)

# %%
inv_vref_values
# Out:
# [300,
#  350,
#  400,
#  450,
#  500,
#  550,
#  600,
#  650,
#  700,
#  750,
#  800,
#  850,
#  900,
#  950,
#  1000,
#  1050,
#  1100,
#  1150]

# %%
with open ('link_0_inv_vref_scan.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['REFERENCEVOLTAGE_0.INV_VREF'])
    writer.writerows([[val] for val in inv_vref_values])

# %%
with open ('dacb_settings.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['CH_24.DACB'])
    writer.writerows(dacb_values)
with open ('triminv_scan.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['CH_15.TRIM_INV'])
    writer.writerows(trim_inv_values)

# %%
settings = pd.read_csv('settings.csv')

# %%
settings
# Out:
#      CH_24.DACB
# 0          -128
# 1          -127
# 2          -126
# 3          -125
# 4          -124
# ..          ...
# 251         123
# 252         124
# 253         125
# 254         126
# 255         127
#
# [256 rows x 1 columns]

# %%
ch_names = []
high_trim_inv = 64
for i in range(72):
    name = "CH_" + str(i)
    ch_names.append(name)

# %%
with open ('high_triminv_test.txt', 'w') as  f:
    high_trim_inv = 64
    f.write('ROC')
    f.write('\n')
    for i in range (72):
        f.write('POKE')
        f.write('\n')
        f.write(ch_names[i])
        f.write('\n')
        f.write('TRIM_INV')
        f.write('\n')
        f.write('64')
        f.write('\n')
    f.write ('DUMP')
    f.write('\n')
    f.write('high_triminv_testsettings.yaml')
    f.write('\n')
    f.write('EXIT')
    f.write('\n')
    f.write('EXIT')

# %%
with open ('default_triminv_test.txt', 'w') as  f:
    def_trim_inv = 0
    f.write('ROC')
    f.write('\n')
    for i in range (72):
        f.write('POKE')
        f.write('\n')
        f.write(ch_names[i])
        f.write('\n')
        f.write('TRIM_INV')
        f.write('\n')
        f.write(str(def_trim_inv))
        f.write('\n')
    f.write ('DUMP')
    f.write('\n')
    f.write('default_testsettings.yaml')
    f.write('\n')
    f.write('EXIT')
    f.write('\n')
    f.write('EXIT')

# %%
for i in range(5) :
    print (ch_names[i])
# Out:
# CH_0
# CH_1
# CH_2
# CH_3
# CH_4

# %%
dacb = [0,31]
sign_dac = 1
with open ('neg_high_dacb_test.txt', 'w') as  f:
    f.write('ROC')
    f.write('\n')
    for i in ch_names:
        f.write('POKE')
        f.write('\n')
        f.write(i)
        f.write('\n')
        f.write('DACB')
        f.write('\n')
        f.write('31')
        f.write('\n')
        f.write('POKE')
        f.write('\n')
        f.write(i)
        f.write('\n')
        f.write('SIGN_DAC')
        f.write('\n')
        f.write('1')
        f.write('\n')        
    f.write('EXIT')
    f.write('\n')
    f.write('EXIT')
